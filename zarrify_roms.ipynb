# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from postprocess import *
# Load all data and process it into grid variables
ds = load_data()

# Output single time (and the snapshots on both sides of it)
ds.isel(time=[0], time_bounds=[0,1]).to_zarr("rrexnum200.zarr", zarr_format=2, mode="w");
